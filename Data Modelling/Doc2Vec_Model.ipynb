# %% [markdown]
# # Model
#
# This notebook builds a Doc2Vec model for matching course descriptions to job descriptions. It trains the model on a corpus of course descriptions (from the Coursera catalog). Then it evaluates the model by testing it out with a sample set of job descriptions for which relevant courses have already been pre-selected. Finally, the model is "pickled" for use in an API.

# %%
# Import libraries

import numpy as np
import pandas as pd
import gensim
from scipy.spatial import distance
import pickle

# %% [markdown]
# ## Model Building

# %%
# Read in the course data

course_df = pd.read_csv('../Data/Course_Data/Coursera_Catalog.csv')
print(course_df.shape)
course_df.head(2)
# Out:
# (4416, 10)
#     courseType                                        description  \
# 0  v2.ondemand  Gamification is the application of game elemen...
# 1  v2.ondemand  This course will cover the steps used in weigh...
#
#                                          domainTypes                      id  \
# 0  [{'subdomainId': 'design-and-product', 'domain...  69Bku0KoEeWZtA4u62x6lQ
# 1  [{'subdomainId': 'data-analysis', 'domainId': ...  0HiU7Oe4EeWTAQ4yevf_oQ
#
#            slug specializations                          workload  \
# 0  gamification              []                    4-8 hours/week
# 1  missing-data              []  4 weeks of study, 1-2 hours/week
#
#   primaryLanguages                        certificates  \
# 0           ['en']                    ['VerifiedCert']
# 1           ['en']  ['VerifiedCert', 'Specialization']
#
#                         name
# 0               Gamification
# 1  Dealing With Missing Data

# %%
# Preprocess the course data as a training corpus

# Convert the course descriptions to a list
course_descriptions = course_df['description'].to_list()

# Define a function for basic preprocessing:
# tokenize, lowercase, de-punctuate, document tagging
def read_corpus(corpus):
    for i, doc in enumerate(corpus):
        tokens = gensim.utils.simple_preprocess(doc)
        yield gensim.models.doc2vec.TaggedDocument(tokens, [i])

# Run the function on the list of course descriptions
train_corpus = list(read_corpus(course_descriptions))

# %%
# Examine the first document in the corpus (tag at end)

print(train_corpus[0])
# Out:
# TaggedDocument(['gamification', 'is', 'the', 'application', 'of', 'game', 'elements', 'and', 'digital', 'game', 'design', 'techniques', 'to', 'non', 'game', 'problems', 'such', 'as', 'business', 'and', 'social', 'impact', 'challenges', 'this', 'course', 'will', 'teach', 'you', 'the', 'mechanisms', 'of', 'gamification', 'why', 'it', 'has', 'such', 'tremendous', 'potential', 'and', 'how', 'to', 'use', 'it', 'effectively', 'for', 'additional', 'information', 'on', 'the', 'concepts', 'described', 'in', 'the', 'course', 'you', 'can', 'purchase', 'professor', 'werbach', 'book', 'for', 'the', 'win', 'how', 'game', 'thinking', 'can', 'revolutionize', 'your', 'business', 'in', 'print', 'or', 'ebook', 'format', 'in', 'several', 'languages'], [0])

# %%
# Build a model

# Instantiate the model
model = gensim.models.doc2vec.Doc2Vec(vector_size=50,
                                      window=5,
                                      dm=0, # PV-DBOW
                                      dm_concat=1,
                                      min_count=2,
                                      epochs=10)

# Create a vocabulary for the model
model.build_vocab(train_corpus)

# Train the model on the corpus
model.train(train_corpus,
            total_examples=model.corpus_count,
            epochs=model.epochs)

# %%
# Self-assess the model

# Infer a vector for a document in the training corpus itself.
vector = model.infer_vector(train_corpus[0].words)

# Find which documents in the training corpus it is most similar to.
sims = model.docvecs.most_similar([vector])
sims
# Out:
# [(0, 0.968474805355072),
#  (3723, 0.9504928588867188),
#  (4182, 0.9456918239593506),
#  (2938, 0.9443598985671997),
#  (184, 0.9437819123268127),
#  (2078, 0.9434263706207275),
#  (2663, 0.9420011043548584),
#  (3979, 0.9406683444976807),
#  (599, 0.9404467344284058),
#  (688, 0.9402422904968262)]

# %% [markdown]
# ### Analysis:
# The model successfully finds that the queried document is most similar to itself in the training corpus, with a similarity score of over 96%.

# %% [markdown]
# ## Model Evaluation

# %%
# Read in the sample job descriptions

jobs_test_sample = pd.read_csv('../EDA/jobs_test_sample.csv')
jobs_test_sample
# Out:
#         Job_title                                           Job_Desc  Job_id
# 0  Data Scientist  We are looking for Data Scientists who are int...     901
# 1  Data Scientist  The world's largest and fastest-growing compan...     910
# 2  Data Scientist  \nRole: Data Scientist.\n\nLocation: Foster Ci...     916
# 3  Data Scientist  Upstart is the leading AI lending platform par...     920
# 4  Data Scientist  Why Divvy?Over the past decade, millions of Am...     938
# 5   Data Engineer  About Rocket LawyerWe believe everyone deserve...     935
# 6   Data Engineer  Our mission is to create a world where mental ...    1068
# 7   Data Engineer  Data Engineer \nIf you are a Data Engineer wit...    1089
# 8   Data Engineer  Prabhav Services Inc. is one of the premier pr...    1100
# 9   Data Engineer  About Skupos\nSkupos is the data platform for ...    1105

# %%
# Read in the sample courses relevant to the job descriptions

courses_test_sample = pd.read_csv('../EDA/courses_test_sample.csv')
courses_test_sample
# Out:
#                                                 name  \
# 0                       The Data Scientist’s Toolbox
# 1                                   Machine Learning
# 2                 Applied Machine Learning in Python
# 3                     Data Visualization with Python
# 4                       Machine Learning with Python
# 5                 Databases and SQL for Data Science
# 6  Google Cloud Platform Big Data and Machine Lea...
# 7           Big Data Modeling and Management Systems
# 8                     Database Management Essentials
# 9  Data Warehouse Concepts, Design, and Data Inte...
#
#                                          description       job_title  \
# 0  In this course you will get an introduction to...  Data Scientist
# 1  Machine learning is the science of getting com...  Data Scientist
# 2  This course will introduce the learner to appl...  Data Scientist
# 3  "A picture is worth a thousand words". We are ...  Data Scientist
# 4  This course dives into the basics of machine l...  Data Scientist
# 5  Much of the world's data resides in databases....   Data Engineer
# 6  This 2-week accelerated on-demand course intro...   Data Engineer
# 7  Once you’ve identified a big data issue to ana...   Data Engineer
# 8  Database Management Essentials provides the fo...   Data Engineer
# 9  This is the second course in the Data Warehous...   Data Engineer
#
#    course_id
# 0       3823
# 1        143
# 2       3165
# 3       3588
# 4       2517
# 5        545
# 6       1015
# 7       4233
# 8       3763
# 9       1311

# %%
# Split the sample courses by job title

ds_courses = courses_test_sample.loc[courses_test_sample['job_title'] == "Data Scientist"]
de_courses = courses_test_sample.loc[courses_test_sample['job_title'] == "Data Engineer"]
de_courses.reset_index(drop=True, inplace=True)

# %%
# Calculate the model's distance score for this sample data:
# A lower score is better because the model should recognize
# that these jobs and courses are similar to each other.

# Initiate a list of distances
distances = []

# Loop through the labeled jobs
for i in range(len(jobs_test_sample)):
    
    # Extract the information for the job
    job_title, job_desc, job_id = jobs_test_sample.iloc[i]
    
    # Preprocess the job description
    doc = gensim.utils.simple_preprocess(job_desc)
    
    # Convert the job description into a vector
    job_vec = model.infer_vector(doc)
    
    # Check the job title and loop through relevant courses
    if job_title == 'Data Scientist':
        
        for j in range(len(ds_courses)):
            
            # Extract the course id
            course_id = ds_courses.iloc[j,3]
            
            # Find the distance between the job and course
            d = distance.cosine(job_vec, model.docvecs[course_id])
            
            # Add the result to the distance list
            distances.append(d)
            
    if job_title == 'Data Engineer':
        
        for j in range(len(de_courses)):
            
            # Extract the course id
            course_id = de_courses.iloc[j,3]
            
            # Find the distance between the job and course
            d = distance.cosine(job_vec, model.docvecs[course_id])
            
            # Add the result to the distance list
            distances.append(d)

# Calculate the average distance for all job descriptions
sum_dist = 0
for d in distances:
    sum_dist += d

avg_dist = round(sum_dist / len(distances), 3)
min_dist = round(min(distances), 3)
max_dist = round(max(distances), 3)

print(f"Mean distance score: {avg_dist}")
print(f"Min distance score: {min_dist}")
print(f"Max distance score: {max_dist}")
# Out:
# Mean distance score: 0.165
# Min distance score: 0.059
# Max distance score: 0.284

# %% [markdown]
# ## Detailed Results

# %%
# Define a function to display the results for each labeled job

def display_recs(job_id):
    
    # Initialize a dictionary for the job
    job_dict = {}
    keys = ['job_id', 'job_title', 'course_id', 'course_name', 'selected', 'distance']
    for key in keys:
        job_dict[key] = []
    
    # Extract info about the job
    i = jobs_test_sample.loc[jobs_test_sample['Job_id'] == job_id].index.values[0]
    job_title = jobs_test_sample.iloc[i]['Job_title']
    job_desc = jobs_test_sample.iloc[i]['Job_Desc']
    
    # Preprocess the job description
    doc = gensim.utils.simple_preprocess(job_desc)
    
    # Convert the job description into a vector
    job_vec = model.infer_vector(doc)
    
    # Get top 5 courses from the model
    top_recs = model.docvecs.most_similar(positive=[job_vec], topn=5)
    
    # Loop through top 5 courses
    for rec in top_recs:
        
        # Add job info to the dictionary
        job_dict['job_id'].append(job_id)
        job_dict['job_title'].append(job_title)
        
        # Add course info to the dicitonary
        course_id = rec[0]
        job_dict['course_id'].append(course_id)
        course_name = course_df.loc[course_id, 'name']
        job_dict['course_name'].append(course_name)
        job_dict['selected'].append(0)
        
        # Add the distance score to the dictionary
        d = round((1-rec[1]), 3)
        job_dict['distance'].append(d)
    
    # Now loop through the courses pre-selected as relevant
    if job_title == 'Data Scientist':
        
        for i in range(len(ds_courses)):
            
            # Add job info to the dictionary
            job_dict['job_id'].append(job_id)
            job_dict['job_title'].append(job_title)
            
            # Add course info to the dictionary
            course_id = ds_courses.iloc[i,3]
            job_dict['course_id'].append(course_id)
            course_name = ds_courses.iloc[i,0]
            job_dict['course_name'].append(course_name)
            job_dict['selected'].append(1)
            
            # Find and add the distance score to the dictionary
            d = distance.cosine(job_vec, model.docvecs[course_id])
            d = round(d,3)
            job_dict['distance'].append(d)
            
    if job_title == 'Data Engineer':
        
        for i in range(len(de_courses)):
            
            # Add job info to the dictionary
            job_dict['job_id'].append(job_id)
            job_dict['job_title'].append(job_title)
            
            # Add course info to the dictionary
            course_id = de_courses.iloc[i,3]
            job_dict['course_id'].append(course_id)
            course_name = de_courses.iloc[i,0]
            job_dict['course_name'].append(course_name)
            job_dict['selected'].append(1)
            
            # Find and add the distance score to the dictionary
            d = distance.cosine(job_vec, model.docvecs[course_id])
            d = round(d,3)
            job_dict['distance'].append(d)
    
    # Convert the dictionary into a dataframe
    df = pd.DataFrame(job_dict)
    
    # Rank by distance
    df = df.sort_values('distance')
    
    return df

# %%
# Job 1
display_recs(901)
# Out:
#    job_id       job_title  course_id  \
# 0     901  Data Scientist       1721
# 1     901  Data Scientist       4024
# 2     901  Data Scientist       2316
# 3     901  Data Scientist       1942
# 4     901  Data Scientist       1719
# 8     901  Data Scientist       3588
# 7     901  Data Scientist       3165
# 5     901  Data Scientist       3823
# 6     901  Data Scientist        143
# 9     901  Data Scientist       2517
#
#                                          course_name  selected  distance
# 0              New Technologies for Business Leaders         0     0.096
# 1               Research Data Management and Sharing         0     0.101
# 2  Big Data Essentials: HDFS, MapReduce and Spark...         0     0.103
# 3    Performance Assessment in the Virtual Classroom         0     0.106
# 4  Introduction to Business Analytics: Communicat...         0     0.106
# 8                     Data Visualization with Python         1     0.146
# 7                 Applied Machine Learning in Python         1     0.147
# 5                       The Data Scientist’s Toolbox         1     0.151
# 6                                   Machine Learning         1     0.184
# 9                       Machine Learning with Python         1     0.191

# %%
# Job 2
display_recs(910)
# Out:
#    job_id       job_title  course_id  \
# 0     910  Data Scientist       3049
# 1     910  Data Scientist       3384
# 2     910  Data Scientist       3120
# 3     910  Data Scientist       2663
# 4     910  Data Scientist       1721
# 8     910  Data Scientist       3588
# 5     910  Data Scientist       3823
# 9     910  Data Scientist       2517
# 7     910  Data Scientist       3165
# 6     910  Data Scientist        143
#
#                                        course_name  selected  distance
# 0                   Big Data Emerging Technologies         0     0.148
# 1                     Building a Data Science Team         0     0.149
# 2  Digital Product Management: Modern Fundamentals         0     0.154
# 3                              Marketing Analytics         0     0.156
# 4            New Technologies for Business Leaders         0     0.157
# 8                   Data Visualization with Python         1     0.212
# 5                     The Data Scientist’s Toolbox         1     0.213
# 9                     Machine Learning with Python         1     0.237
# 7               Applied Machine Learning in Python         1     0.251
# 6                                 Machine Learning         1     0.254

# %%
# Job 3
display_recs(916)
# Out:
#    job_id       job_title  course_id                           course_name  \
# 0     916  Data Scientist        602  Data Science for Business Innovation
# 1     916  Data Scientist       1752                 Statistical Inference
# 2     916  Data Scientist        272              Data Science Methodology
# 3     916  Data Scientist         27                Code Free Data Science
# 4     916  Data Scientist       1235                      Data in Database
# 8     916  Data Scientist       3588        Data Visualization with Python
# 5     916  Data Scientist       3823          The Data Scientist’s Toolbox
# 7     916  Data Scientist       3165    Applied Machine Learning in Python
# 6     916  Data Scientist        143                      Machine Learning
# 9     916  Data Scientist       2517          Machine Learning with Python
#
#    selected  distance
# 0         0     0.046
# 1         0     0.050
# 2         0     0.051
# 3         0     0.055
# 4         0     0.056
# 8         1     0.058
# 5         1     0.076
# 7         1     0.081
# 6         1     0.105
# 9         1     0.128

# %%
# Job 4
display_recs(920)
# Out:
#    job_id       job_title  course_id  \
# 0     920  Data Scientist       2316
# 1     920  Data Scientist       3044
# 2     920  Data Scientist       3384
# 3     920  Data Scientist        272
# 4     920  Data Scientist       2653
# 6     920  Data Scientist        143
# 8     920  Data Scientist       3588
# 9     920  Data Scientist       2517
# 5     920  Data Scientist       3823
# 7     920  Data Scientist       3165
#
#                                          course_name  selected  distance
# 0  Big Data Essentials: HDFS, MapReduce and Spark...         0     0.093
# 1  Big Data Analysis: Hive, Spark SQL, DataFrames...         0     0.098
# 2                       Building a Data Science Team         0     0.105
# 3                           Data Science Methodology         0     0.105
# 4      Big Data, Artificial Intelligence, and Ethics         0     0.110
# 6                                   Machine Learning         1     0.138
# 8                     Data Visualization with Python         1     0.143
# 9                       Machine Learning with Python         1     0.145
# 5                       The Data Scientist’s Toolbox         1     0.167
# 7                 Applied Machine Learning in Python         1     0.186

# %%
# Job 5
display_recs(938)
# Out:
#    job_id       job_title  course_id  \
# 0     938  Data Scientist       3049
# 1     938  Data Scientist        272
# 2     938  Data Scientist       4145
# 3     938  Data Scientist        381
# 4     938  Data Scientist       3776
# 8     938  Data Scientist       3588
# 5     938  Data Scientist       3823
# 9     938  Data Scientist       2517
# 6     938  Data Scientist        143
# 7     938  Data Scientist       3165
#
#                                    course_name  selected  distance
# 0               Big Data Emerging Technologies         0     0.079
# 1                     Data Science Methodology         0     0.084
# 2  Foundations of strategic business analytics         0     0.086
# 3        Business Analytics Executive Overview         0     0.088
# 4        Data Management for Clinical Research         0     0.088
# 8               Data Visualization with Python         1     0.106
# 5                 The Data Scientist’s Toolbox         1     0.112
# 9                 Machine Learning with Python         1     0.142
# 6                             Machine Learning         1     0.144
# 7           Applied Machine Learning in Python         1     0.150

# %%
# Job 6
display_recs(935)
# Out:
#    job_id      job_title  course_id  \
# 0     935  Data Engineer       1443
# 1     935  Data Engineer       3049
# 2     935  Data Engineer       2465
# 3     935  Data Engineer        671
# 4     935  Data Engineer         95
# 9     935  Data Engineer       1311
# 6     935  Data Engineer       1015
# 7     935  Data Engineer       4233
# 8     935  Data Engineer       3763
# 5     935  Data Engineer        545
#
#                                          course_name  selected  distance
# 0  IoT (Internet of Things) Wireless & Cloud Comp...         0     0.128
# 1                     Big Data Emerging Technologies         0     0.129
# 2  Business Intelligence Concepts, Tools, and App...         0     0.132
# 3    Relational Database Support for Data Warehouses         0     0.134
# 4                  Google Cloud Product Fundamentals         0     0.136
# 9  Data Warehouse Concepts, Design, and Data Inte...         1     0.152
# 6  Google Cloud Platform Big Data and Machine Lea...         1     0.155
# 7           Big Data Modeling and Management Systems         1     0.165
# 8                     Database Management Essentials         1     0.174
# 5                 Databases and SQL for Data Science         1     0.185

# %%
# Job 7
display_recs(1068)
# Out:
#    job_id      job_title  course_id  \
# 0    1068  Data Engineer       3044
# 1    1068  Data Engineer       2316
# 2    1068  Data Engineer       3831
# 3    1068  Data Engineer       1998
# 4    1068  Data Engineer       3496
# 7    1068  Data Engineer       4233
# 5    1068  Data Engineer        545
# 6    1068  Data Engineer       1015
# 9    1068  Data Engineer       1311
# 8    1068  Data Engineer       3763
#
#                                          course_name  selected  distance
# 0  Big Data Analysis: Hive, Spark SQL, DataFrames...         0     0.179
# 1  Big Data Essentials: HDFS, MapReduce and Spark...         0     0.200
# 2          Surveillance Systems: The Building Blocks         0     0.205
# 3  Teaching Impacts of Technology: Workplace of t...         0     0.205
# 4  Teaching Impacts of Technology: Data Collectio...         0     0.211
# 7           Big Data Modeling and Management Systems         1     0.230
# 5                 Databases and SQL for Data Science         1     0.248
# 6  Google Cloud Platform Big Data and Machine Lea...         1     0.261
# 9  Data Warehouse Concepts, Design, and Data Inte...         1     0.270
# 8                     Database Management Essentials         1     0.278

# %%
# Job 8
display_recs(1089)
# Out:
#    job_id      job_title  course_id  \
# 0    1089  Data Engineer       3044
# 1    1089  Data Engineer       2548
# 2    1089  Data Engineer        225
# 3    1089  Data Engineer       3776
# 4    1089  Data Engineer       3148
# 7    1089  Data Engineer       4233
# 5    1089  Data Engineer        545
# 8    1089  Data Engineer       3763
# 9    1089  Data Engineer       1311
# 6    1089  Data Engineer       1015
#
#                                          course_name  selected  distance
# 0  Big Data Analysis: Hive, Spark SQL, DataFrames...         0     0.101
# 1                               Requirements Writing         0     0.121
# 2                      Big Data, Genes, and Medicine         0     0.121
# 3              Data Management for Clinical Research         0     0.126
# 4      Retrieve Data from Multiple-Table SQL Queries         0     0.128
# 7           Big Data Modeling and Management Systems         1     0.171
# 5                 Databases and SQL for Data Science         1     0.173
# 8                     Database Management Essentials         1     0.174
# 9  Data Warehouse Concepts, Design, and Data Inte...         1     0.178
# 6  Google Cloud Platform Big Data and Machine Lea...         1     0.248

# %%
# Job 9
display_recs(1100)
# Out:
#    job_id      job_title  course_id  \
# 0    1100  Data Engineer       3726
# 1    1100  Data Engineer       2099
# 2    1100  Data Engineer        985
# 3    1100  Data Engineer       4233
# 7    1100  Data Engineer       4233
# 4    1100  Data Engineer       3976
# 9    1100  Data Engineer       1311
# 5    1100  Data Engineer        545
# 8    1100  Data Engineer       3763
# 6    1100  Data Engineer       1015
#
#                                          course_name  selected  distance
# 0   Introduction to FPGA Design for Embedded Systems         0     0.076
# 1                           Introduction to Big Data         0     0.078
# 2                   Cloud Computing Concepts, Part 1         0     0.080
# 3           Big Data Modeling and Management Systems         0     0.080
# 7           Big Data Modeling and Management Systems         1     0.080
# 4                Big Data Integration and Processing         0     0.084
# 9  Data Warehouse Concepts, Design, and Data Inte...         1     0.101
# 5                 Databases and SQL for Data Science         1     0.102
# 8                     Database Management Essentials         1     0.109
# 6  Google Cloud Platform Big Data and Machine Lea...         1     0.152

# %%
# Job 10
display_recs(1105)
# Out:
#    job_id      job_title  course_id  \
# 0    1105  Data Engineer       3044
# 1    1105  Data Engineer       3049
# 2    1105  Data Engineer       4236
# 3    1105  Data Engineer       3543
# 4    1105  Data Engineer         95
# 7    1105  Data Engineer       4233
# 9    1105  Data Engineer       1311
# 8    1105  Data Engineer       3763
# 5    1105  Data Engineer        545
# 6    1105  Data Engineer       1015
#
#                                          course_name  selected  distance
# 0  Big Data Analysis: Hive, Spark SQL, DataFrames...         0     0.114
# 1                     Big Data Emerging Technologies         0     0.119
# 2          Business Transformation with Google Cloud         0     0.123
# 3  Create Relational Database Table Using SQLiteS...         0     0.127
# 4                  Google Cloud Product Fundamentals         0     0.136
# 7           Big Data Modeling and Management Systems         1     0.140
# 9  Data Warehouse Concepts, Design, and Data Inte...         1     0.149
# 8                     Database Management Essentials         1     0.158
# 5                 Databases and SQL for Data Science         1     0.162
# 6  Google Cloud Platform Big Data and Machine Lea...         1     0.180

# %% [markdown]
# ### Analysis:
# The architecture works, but the model's performance is not great. It is finding relevant courses, but almost definitely not the most relevant ones in the catalog for job seekers.

# %% [markdown]
# ## Pickle the Model

# %%
# Save the model for use in the API
# by serializing it with the pickle library.

pickle.dump(model, open('../model.p', 'wb'))
